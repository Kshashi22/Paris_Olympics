# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshashi22/Paris_Olympics/blob/main/Paris_Olympics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.DataFrame()

# %%
df=pd.read_csv('/content/Paris Olmypics total medal tally 2024 - Sheet1.csv')

# %%
df.head()
# Out:
#    Position              Country  Gold  Silver  Bronze  Total Medals
# 0         1  United States (USA)    40      44      43           127
# 1         2          China (CHN)    40      27      24            91
# 2         3          Japan (JPN)    20      12      13            45
# 3         4      Australia (AUS)    18      19      16            53
# 4         5         France (FRA)    16      26      22            64

# %%
df. tail()
# Out:
#     Position            Country  Gold  Silver  Bronze  Total Medals
# 85        86  Ivory Coast (CIV)     0       0       1             1
# 86        87     Slovakia (SVK)     0       0       1             1
# 87        88         Peru (PER)     0       0       1             1
# 88        89    Singapore (SGP)     0       0       1             1
# 89        90       Zambia (ZAM)     0       0       1             1

# %%
df.dtypes
# Out:
# Position         int64
# Country         object
# Gold             int64
# Silver           int64
# Bronze           int64
# Total Medals     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Position      90 non-null     int64
#  1   Country       90 non-null     object
#  2   Gold          90 non-null     int64
#  3   Silver        90 non-null     int64
#  4   Bronze        90 non-null     int64
#  5   Total Medals  90 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 4.3+ KB

# %%
df.shape
# Out:
# (90, 6)

# %% [markdown]
# ## **Overall Statstics**

# %%
df.describe()
# Out:
#         Position       Gold     Silver     Bronze  Total Medals
# count  90.000000  90.000000  90.000000  90.000000     90.000000
# mean   45.500000   3.644444   3.622222   4.288889     11.555556
# std    26.124701   7.017332   6.803135   6.638743     19.843835
# min     1.000000   0.000000   0.000000   0.000000      1.000000
# 25%    23.250000   0.000000   0.000000   1.000000      2.000000
# 50%    45.500000   1.000000   1.000000   2.000000      5.000000
# 75%    67.750000   3.000000   3.000000   5.000000      9.000000
# max    90.000000  40.000000  44.000000  43.000000    127.000000

# %%
df.describe(include='all')
# Out:
#          Position              Country       Gold     Silver     Bronze  \
# count   90.000000                   90  90.000000  90.000000  90.000000
# unique        NaN                   90        NaN        NaN        NaN
# top           NaN  United States (USA)        NaN        NaN        NaN
# freq          NaN                    1        NaN        NaN        NaN
# mean    45.500000                  NaN   3.644444   3.622222   4.288889
# std     26.124701                  NaN   7.017332   6.803135   6.638743
# min      1.000000                  NaN   0.000000   0.000000   0.000000
# 25%     23.250000                  NaN   0.000000   0.000000   1.000000
# 50%     45.500000                  NaN   1.000000   1.000000   2.000000
# 75%     67.750000                  NaN   3.000000   3.000000   5.000000
# max     90.000000                  NaN  40.000000  44.000000  43.000000
#
#         Total Medals
# count      90.000000
# unique           NaN
# top              NaN
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
df.isnull().sum()
# Out:
# Position        0
# Country         0
# Gold            0
# Silver          0
# Bronze          0
# Total Medals    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
per_null = df.isnull().sum()/len(df)*100
per_null
# Out:
# Position        0.0
# Country         0.0
# Gold            0.0
# Silver          0.0
# Bronze          0.0
# Total Medals    0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Position', 'Country', 'Gold', 'Silver', 'Bronze', 'Total Medals'], dtype='object')

# %% [markdown]
# ## **Checking Duplicates**

# %%
dup_df = df.duplicated().any()
print("Any duplicate data?",dup_df)
# Out:
# Any duplicate data? False

# %% [markdown]
# ## **Total Country**

# %%
df['Country'].value_counts()
# Out:
# Country
# United States (USA)     1
# North Korea (PRK)       1
# Armenia (ARM)           1
# Mexico (MEX)            1
# Turkey (TUR)            1
#                        ..
# Georgia (GEO)           1
# Poland (POL)            1
# Czech Republic (CZE)    1
# Serbia (SRB)            1
# Zambia (ZAM)            1
# Name: count, Length: 90, dtype: int64

# %%
plt.figure(figsize=(25,7))
sns.barplot(x='Country',y='Position',data=df)
plt.xticks(rotation=75)
plt.title("Position of Country")
plt.show()

# %% [markdown]
# ## ***Gold for a Country***

# %%
df['Gold'].value_counts()
# Out:
# Gold
# 0     27
# 1     22
# 2     14
# 3      8
# 4      4
# 12     2
# 40     2
# 13     1
# 10     1
# 20     1
# 8      1
# 6      1
# 5      1
# 14     1
# 15     1
# 16     1
# 18     1
# 9      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='Country',y='Gold',data=df)
plt.xticks(rotation=75)
plt.title("Gold of a Country")
plt.show()

# %% [markdown]
# ## ***Silver for a Country***

# %%
df['Silver'].value_counts()
# Out:
# Silver
# 0     26
# 1     22
# 2     11
# 3     10
# 7      5
# 4      4
# 13     2
# 5      2
# 44     1
# 27     1
# 12     1
# 19     1
# 26     1
# 22     1
# 9      1
# 6      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='Country',y='Silver',data=df)
plt.xticks(rotation=75)
plt.title("Silver of a Country")
plt.show()

# %% [markdown]
# ## ***Bronze for a Country***

# %%
df['Bronze'].value_counts()
# Out:
# Bronze
# 1     24
# 2     15
# 3     13
# 0     11
# 5      7
# 6      4
# 4      3
# 10     2
# 9      1
# 11     1
# 43     1
# 24     1
# 15     1
# 29     1
# 12     1
# 22     1
# 16     1
# 13     1
# 8      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='Country',y='Bronze',data=df)
plt.xticks(rotation=75)
plt.title("Bronze of a Country")
plt.show()

# %% [markdown]
# ## ***Total Medals***

# %%
from functools import total_ordering
total_ordering
df['Total']=df['Gold']+df['Silver']+df['Bronze']
df
# Out:
#     Position              Country  Gold  Silver  Bronze  Total Medals  Total
# 0          1  United States (USA)    40      44      43           127    127
# 1          2          China (CHN)    40      27      24            91     91
# 2          3          Japan (JPN)    20      12      13            45     45
# 3          4      Australia (AUS)    18      19      16            53     53
# 4          5         France (FRA)    16      26      22            64     64
# ..       ...                  ...   ...     ...     ...           ...    ...
# 85        86    Ivory Coast (CIV)     0       0       1             1      1
# 86        87       Slovakia (SVK)     0       0       1             1      1
# 87        88           Peru (PER)     0       0       1             1      1
# 88        89      Singapore (SGP)     0       0       1             1      1
# 89        90         Zambia (ZAM)     0       0       1             1      1
#
# [90 rows x 7 columns]
